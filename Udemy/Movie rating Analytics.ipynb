# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sanja'

# %%
#1. Identifying the Categorical datas:

# %%
movies=pd.read_csv('P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRatings','Budget','Year']

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  Budget  \
# 0    (500) Days of Summer      Comedy            87               81       8
# 1              10,000 B.C.  Adventure             9               44     105
# 2               12 Rounds      Action            30               52      20
# 3                127 Hours  Adventure            93               84      18
# 4                17 Again      Comedy            55               70      20
# ..                     ...        ...           ...              ...     ...
# 554          Your Highness     Comedy            26               36      50
# 555        Youth in Revolt     Comedy            68               52      18
# 556                 Zodiac   Thriller            89               73      65
# 557            Zombieland      Action            90               87      24
# 558              Zookeeper     Comedy            14               42      80
#
#      Year
# 0    2009
# 1    2008
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings      Budget         Year
# count    559.000000       559.000000  559.000000   559.000000
# mean      47.309481        58.744186   50.236136  2009.152057
# std       26.413091        16.826887   48.731817     1.362632
# min        0.000000         0.000000    0.000000  2007.000000
# 25%       25.000000        47.000000   20.000000  2008.000000
# 50%       46.000000        58.000000   35.000000  2009.000000
# 75%       70.000000        72.000000   65.000000  2010.000000
# max       97.000000        96.000000  300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings      Budget
# count    559.000000       559.000000  559.000000
# mean      47.309481        58.744186   50.236136
# std       26.413091        16.826887   48.731817
# min        0.000000         0.000000    0.000000
# 25%       25.000000        47.000000   20.000000
# 50%       46.000000        58.000000   35.000000
# 75%       70.000000        72.000000   65.000000
# max       97.000000        96.000000  300.000000

# %% [markdown]
# ---

# %%
# 2. Working with JointPlots:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j1=sns.jointplot(data=movies,x='CriticRating',y='AudienceRatings')

# %%
j1=sns.jointplot(data=movies,x='CriticRating',y='AudienceRatings',kind='hex')

# %%
#>>>Chart no.1

# %%
j1=sns.jointplot(data=movies,x='CriticRating',y='Budget',color='g')

# %%
j1

# %% [markdown]
# ---

# %%
#Histogram:

# %%
sns.set_style('darkgrid')
m1=sns.distplot(movies.AudienceRatings,bins=15)

# %%
sns.set_style('white')
n1=plt.hist(movies.AudienceRatings, bins=15)

# %%
n1=plt.hist(movies.CriticRating, bins=15)

# %%
#Stacked Histogram:

# %%
h1=plt.hist(movies.Budget)

# %%
movies[movies.Genre=='Drama'].Budget
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: Budget, Length: 101, dtype: int64

# %%
h1=plt.hist(movies[movies.Genre=='Drama'].Budget)

# %%
plt.hist(movies[movies.Genre=='Action'].Budget)
plt.hist(movies[movies.Genre=='Drama'].Budget)
plt.hist(movies[movies.Genre=='Thriller'].Budget)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].Budget,movies[movies.Genre=='Drama'].Budget,movies[movies.Genre=='Thriller'].Budget])
plt.legend(movies.Genre.cat.categories)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].Budget,\
          movies[movies.Genre=='Drama'].Budget,\
          movies[movies.Genre=='Thriller'].Budget],\
          bins=20,stacked=True)
plt.legend(movies.Genre.cat.categories)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
#Practicing Problem:

list1=[]
mylable=[]
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].Budget)
    mylable.append(gen)
h1=plt.hist(list1,bins=20,stacked=True,rwidth=1,label=mylable) 
plt.legend()

# %%
list1=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].Budget)
print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: Budget, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: Budget, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
#        ..
# 552    80
# 553    22
# 554    50
# 555    18
# 558    80
# Name: Budget, Length: 172, dtype: int64, 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: Budget, Length: 101, dtype: int64, 7      32
# 12     35
# 20     40
# 28      5
# 59     26
# ...

# %%
list1=list()
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].Budget)
    mylabels.append(gen)
h1=plt.hist(list1,bins=20, stacked=True,rwidth=1,label=mylabels,)  #rwidth where no gaps comes inbetween the bins
plt.legend()

# %%
#Creating KDE Plot:

# %%
#fit_reg = False means no regression (linear)line comes in between them
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRatings',fit_reg=False,hue='Genre',\
                 size=7, aspect=1)

# %%
h1=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
#here below shows more density at centre ie.@20,41 and how it is distributed from it.

# %%
h1=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
h1=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='Reds')
#little bit smoother than the above picture

# %% [markdown]
# ---

# %%
#Working with SubPlots:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('dark')
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings)
#below diagram represents normal distribution

# %%
#here its uniform distribution
k1=sns.kdeplot(movies.Budget,movies.CriticRating)

# %%
f,axes=plt.subplots(2,2,figsize=(12,6))
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0,1])
k1=sns.kdeplot(movies.Budget,movies.CriticRating,ax=axes[1,1])

# %%
f,axes=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True) #1,2 indicate the no. of rows and columns
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0])
k2=sns.kdeplot(movies.Budget,movies.CriticRating,ax=axes[1])
k1.set(xlim=(-20,160)) #gives the xlimit ie.range from -20 to 160 and sharex mentioned above is to share the range forbothk1,k2
# Out:
# [(-20.0, 160.0)]

# %% [markdown]
# ---

# %%
#Violin Plots:

# %%
w=sns.boxplot(data=movies,x='Genre',y='CriticRating')

# %%
z=sns.violinplot(data=movies,x='Genre',y='CriticRating')

# %%
z=sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')
#note:The shorter box indicates that it is more density

# %%
movies[movies.Genre=='Drama']
# Out:
#                     Film  Genre  CriticRating  AudienceRatings  Budget  Year
# 10            88 Minutes  Drama             5               51      30  2007
# 11    A Dangerous Method  Drama            79               89      20  2011
# 13        A Serious Man   Drama            89               64       7  2009
# 18          Albert Nobbs  Drama            53               43       8  2011
# 23       All Good Things  Drama            33               64      20  2010
# ..                   ...    ...           ...              ...     ...   ...
# 529            War Horse  Drama            77               73      66  2011
# 532  Water For Elephants  Drama            60               72      38  2011
# 534     We Own the Night  Drama            55               63      21  2007
# 541             Whip It   Drama            84               73      15  2009
# 545        Winter's Bone  Drama            94               73       2  2010
#
# [101 rows x 6 columns]

# %%
z=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')

# %% [markdown]
# ---

# %%
#Creating a Facet grid:

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre') #Creating facet grid
g=g.map(plt.scatter,'CriticRating','AudienceRatings')   #applying function to facet grid

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'Budget')

# %%
#Back to Scatter Plot
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')#Creating facet grid
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRatings',**kws)   #applying function to facet grid

# %% [markdown]
# ---

# %%
#Controlling axes and adding Diagonal:

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')#Creating facet grid
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRatings',**kws) 
g.set(xlim=(0,100),ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c='grey',ls='--')
g.add_legend()

# %% [markdown]
# ---

# %%
#Building Dashboards:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2,figsize=(10,10))
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0,0])
k2=sns.kdeplot(movies.Budget,movies.CriticRating,ax=axes[0,1])
z=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[1,0])
k4=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4b=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='Reds',ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20.0, 160.0)]

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2,figsize=(10,10))
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,ax=axes[0,0])
k2=sns.kdeplot(movies.Budget,movies.CriticRating,ax=axes[0,1])
z=sns.violinplot(data=movies,x='Year',y='Budget',ax=axes[1,0])
k4=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
k4b=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='Reds',ax=axes[1,1])
#axes[1,1].hist(movies.CriticRating, bins=15)  #since it is not aseaborn another method is used :) 

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# ---

# %%
#Styling Dashboards:

# %%
sns.set_style('dark',{"axes.facecolor":"black"})  #white,whitegrid,dark,darkgrid,ticks
f,axes = plt.subplots(2,2,figsize=(10,10))
#plot1:
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,shade=True,shade_lowest=True,cmap='inferno',\
               ax=axes[0,0])
k1=sns.kdeplot(movies.Budget,movies.AudienceRatings,cmap='cool',\
               ax=axes[0,0])
#plot2:
k2=sns.kdeplot(movies.Budget,movies.CriticRating,shade=True,shade_lowest=True,cmap='inferno',ax=axes[0,1])
k2=sns.kdeplot(movies.Budget,movies.CriticRating,cmap='cool',ax=axes[0,1])
#plot3:
z=sns.violinplot(data=movies,x='Year',y='Budget',ax=axes[1,0],palette='YlOrRd')
#plot4:
k4=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])
k4b=sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='gist_gray_r',ax=axes[1,1])

#axes[1,1].hist(movies.CriticRating, bins=15)  #since it is not aseaborn another method is used :) 

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# ---

# %%
#Finishing Touches:

# %%
list1=[]
mylable=[]
sns.set_style('whitegrid')
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].Budget)
    mylable.append(gen)
fig,ax=plt.subplots() #fixing subplot ie only one subplot
fig.set_size_inches(11.7,8.27) #size of A4 Paper Note: The size can be adjusted by subplots onto data
h1=plt.hist(list1,bins=20,stacked=True,rwidth=1,label=mylable) 
plt.title("Movie Budget Distribution",fontsize=30,color='DarkBlue',fontname='console')
plt.ylabel("Number of movies",fontsize=25,color='Red')
plt.xlabel("Budgets",fontsize=25,color='Green')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(frameon=True,fancybox=True,shadow=True,framealpha=0.8,prop={'size':15}) # or: fontsize='xx-large' ,framealpha is greyish color in legend box
plt.show()
# Out:
# findfont: Font family ['console'] not found. Falling back to DejaVu Sans.

# %%
list1=[]
mylable=[]
sns.set_style('whitegrid')
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].Budget)
    mylable.append(gen)
fig,ax=plt.subplots() #fixing subplot ie only one subplot
fig.set_size_inches(11.7,8.27) #size of A4 Paper Note: The size can be adjusted by subplots onto data
h1=plt.hist(list1,bins=20,stacked=True,rwidth=1,label=mylable,color=['Red','Blue','Green','Yellow','Orange','Pink','Violet']) 
plt.title("Movie Budget Distribution",fontsize=30,color='DarkBlue',fontname='console')
plt.ylabel("Number of movies",fontsize=25,color='Red')
plt.xlabel("Budgets",fontsize=25,color='Green')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(frameon=True,fancybox=True,shadow=True,framealpha=0.8,prop={'size':15}) # or: fontsize='xx-large'
plt.show()
